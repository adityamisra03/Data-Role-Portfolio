# %% [markdown]
# ![CMRN](https://cmrn.systemsbiology.net/static/images/cancerMiRNARegulatoryNetwork.gif)
# # Cancer miRNA regulatory network reconstruction
#
# ### Abstract
# Genes regulated by the same miRNA can be discovered by virtue of their coexpression at the transcriptional level and the presence of a conserved miRNA-binding site in their 3' UTRs. Using this principle we have integrated the three best performing and complementary algorithms into a framework for inference of regulation by miRNAs (FIRM) from sets of coexpressed genes. We demonstrate the utility of FIRM by inferring a cancer-miRNA regulatory network through the analysis of 2,240 gene coexpression signatures from 46 cancers. By analyzing this network for functional enrichment of known hallmarks of cancer we have discovered a subset of 13 miRNAs that regulate oncogenic processes across diverse cancers. We have performed experiments to test predictions from this miRNA-regulatory network to demonstrate that miRNAs of the miR-29 family (miR-29a, miR-29b, and miR-29c) regulate specific genes associated with tissue invasion and metastasis in lung adenocarcinoma. Further, we highlight the specificity of using FIRM inferences to identify miRNA-regulated genes by experimentally validating that miR-767-5p, which partially shares the miR-29 seed sequence, regulates only a subset of miR-29 targets. By providing mechanistic linkage between miRNA dysregulation in cancer, their binding sites in the 3'UTRs of specific sets of coexpressed genes, and their associations with known hallmarks of cancer, FIRM, and the inferred cancer miRNA-regulatory network will serve as a powerful public resource for discovery of potential cancer biomarkers.
#
# [Plaisier CL, Pan M, Baliga NS. A miRNA-regulatory network explains how dysregulated miRNAs perturb oncogenic processes across diverse cancers. Genome Res. 2012 Nov;22(11):2302-14. doi: 10.1101/gr.133991.111. Epub 2012 Jun 28. PMID: 22745231; PMCID: PMC3483559.](https://pubmed.ncbi.nlm.nih.gov/22745231/)
#
# [Cancer miRNA Regulatory Network](https://cmrn.systemsbiology.net/)
#
# ### Goal of todays analyses
# Build a network based on several different statistical analyses:  1) miRNA to target gene enrichment analysis across 2,240 gene co-expression signatures, 2) GO biological process functional enrichment analysis of the same 2,240 co-expression signatures, and 3) semantic similarity of GO term with the hallmarks of cancer. All of these data are located in [Supplementary Table 8](https://genome.cshlp.org/content/suppl/2012/09/13/gr.133991.111.DC1/SuppTab8.xlsx) from [Plaisier, et al. 2012](https://pubmed.ncbi.nlm.nih.gov/22745231/).
#
# ![Network structure](https://genome.cshlp.org/content/22/11/2302/F6.large.jpg)
# **Figure legend**: Summary of FIRM predictions for the miR-29a/b/c and miR-767-5p cancer–miRNA regulatory subnetwork. This subnetwork is included in both the metastatic- and cross-cancer–miRNA regulatory networks. The network is laid out hierarchically with (from the top down) cancers, miRNAs, coexpression signatures, genes that were experimentally validated through luciferase assays, significantly enriched GO biological process terms for the coexpression signature, and finally the GO terms associated with hallmarks of cancers. (Left) The FIRM integration strategy that is a flow of information through this hierarchy, where the red arrows indicate a FIRM prediction. The meanings of the FIRM predictions are described on the right side, where inference of a miRNA regulating a cancer coexpression signature predicts that the miRNA is dysregulated in that cancer. This same inference predicts that the miRNA regulates the genes in the signature, which can be tested experimentally. Functional enrichment of GO term annotations among the coregulated genes predicts the effect of regulating this set of genes, and association of the enriched GO terms with hallmarks of cancer predicts the oncogenic processes that might be affected. (FIRM = framework for inference of regulation by miRNAs)
#
# ### Files for the analysis
# Data files and code for this lecture:
#
# [data_network.zip](https://asu.instructure.com/courses/166212/files/70614348?wrap=1)
# [networkReconstruction.ipynb](https://asu.instructure.com/courses/166212/files/70614350?wrap=1)
# [networkReconstruction.py](https://asu.instructure.com/courses/166212/files/70614351?wrap=1)
#
# Then put them into a working directory and extract the data files so that you have the following directory structure:
#
# ```| Working_Directory
#      -| networkReconstruction.py
#      -| networkReconstruction.ipynb
#      -| data
#          -| hsa_mature.csv
#          -| SuppTab8.csv```
#
# **Descriptions of files:**
# - **data/SuppTab8.csv**:  The Supplementary Table 8 is provided as an Excel spreadsheet, and has been converted into a CSV file. It will be located in the data_network.zip file you downloaded.
# - **data/hsa_mature.csv**:  A file that can be used to translate miRBase from computer friendly mature sequence IDs into human friendly miRNA names.
#
#
#
# ### Packages to install
# You will need to install both pyvis and networkx:

# %%
import sys
# !{sys.executable} -m pip install pyvis
# !{sys.executable} -m pip install networkx
# Out:
# Requirement already satisfied: pyvis in /Users/cplaisie/opt/anaconda3/lib/python3.8/site-packages (0.1.9)
# Requirement already satisfied: jsonpickle>=1.4.1 in /Users/cplaisie/opt/anaconda3/lib/python3.8/site-packages (from pyvis) (2.0.0)
# Requirement already satisfied: jinja2>=2.9.6 in /Users/cplaisie/opt/anaconda3/lib/python3.8/site-packages (from pyvis) (2.11.3)
# Requirement already satisfied: networkx>=1.11 in /Users/cplaisie/opt/anaconda3/lib/python3.8/site-packages (from pyvis) (2.5)
# Requirement already satisfied: ipython>=5.3.0 in /Users/cplaisie/opt/anaconda3/lib/python3.8/site-packages (from pyvis) (7.22.0)
# Requirement already satisfied: jedi>=0.16 in /Users/cplaisie/opt/anaconda3/lib/python3.8/site-packages (from ipython>=5.3.0->pyvis) (0.17.2)
# Requirement already satisfied: traitlets>=4.2 in /Users/cplaisie/opt/anaconda3/lib/python3.8/site-packages (from ipython>=5.3.0->pyvis) (5.0.5)
# Requirement already satisfied: setuptools>=18.5 in /Users/cplaisie/opt/anaconda3/lib/python3.8/site-packages (from ipython>=5.3.0->pyvis) (52.0.0.post20210125)
# Requirement already satisfied: decorator in /Users/cplaisie/opt/anaconda3/lib/python3.8/site-packages (from ipython>=5.3.0->pyvis) (5.1.1)
# Requirement already satisfied: pickleshare in /Users/cplaisie/opt/anaconda3/lib/python3.8/site-packages (from ipython>=5.3.0->pyvis) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/cplaisie/opt/anaconda3/lib/python3.8/site-packages (from ipython>=5.3.0->pyvis) (3.0.17)
# Requirement already satisfied: backcall in /Users/cplaisie/opt/anaconda3/lib/python3.8/site-packages (from ipython>=5.3.0->pyvis) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /Users/cplaisie/opt/anaconda3/lib/python3.8/site-packages (from ipython>=5.3.0->pyvis) (4.8.0)
# Requirement already satisfied: appnope in /Users/cplaisie/opt/anaconda3/lib/python3.8/site-packages (from ipython>=5.3.0->pyvis) (0.1.2)
# Requirement already satisfied: pygments in /Users/cplaisie/opt/anaconda3/lib/python3.8/site-packages (from ipython>=5.3.0->pyvis) (2.8.1)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /Users/cplaisie/opt/anaconda3/lib/python3.8/site-packages (from jedi>=0.16->ipython>=5.3.0->pyvis) (0.7.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/cplaisie/opt/anaconda3/lib/python3.8/site-packages (from jinja2>=2.9.6->pyvis) (1.1.1)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/cplaisie/opt/anaconda3/lib/python3.8/site-packages (from pexpect>4.3->ipython>=5.3.0->pyvis) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/cplaisie/opt/anaconda3/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->pyvis) (0.2.5)
# Requirement already satisfied: ipython-genutils in /Users/cplaisie/opt/anaconda3/lib/python3.8/site-packages (from traitlets>=4.2->ipython>=5.3.0->pyvis) (0.2.0)
# Requirement already satisfied: networkx in /Users/cplaisie/opt/anaconda3/lib/python3.8/site-packages (2.5)
# Requirement already satisfied: decorator>=4.3.0 in /Users/cplaisie/opt/anaconda3/lib/python3.8/site-packages (from networkx) (5.1.1)

# %% [markdown]
# ### Load libraries

# %%
import pandas as pd
from pyvis.network import Network
import networkx as nx

# %% [markdown]
# ### Load up data
# Load up SuppTab8 which has all the information needed:

# %%
st8 = pd.read_csv('data/SuppTab8.csv', header=0, index_col=0)
print(st8.shape)
# Out:
# (314, 13)

# %% [markdown]
# Split out cancer from cluster name and add to DataFrame:

# %%
st8['cancer'] = [i.split(' ')[1] for i in st8.index]
st8
# Out:
#                                                                      GO Terms  \
# Co-expression Signature
# COID Lung Bhattacharjee_24  GO:0051384|GO:0050896|GO:0030155|GO:0007596|GO...
# SMCL Lung Bhattacharjee_61  GO:0019226|GO:0007599|GO:0042127|GO:0007596|GO...
# AC Brain Sun_5              GO:0019730|GO:0050867|GO:0042110|GO:0006928|GO...
# GCT Seminoma Korkola_4      GO:0030301|GO:0042127|GO:0006631|GO:0045907|GO...
# ME Melanoma Hoek_50         GO:0019226|GO:0008104|GO:0007599|GO:0019221|GO...
# ...                                                                       ...
# SRS Ovarian Hendrix_1                        GO:0006139|GO:0010467|GO:0045449
# SRS Ovarian Hendrix_11                       GO:0019058|GO:0019083|GO:0031018
# SRS Ovarian Hendrix_26                                             GO:0008333
# TU Prostate Lapointe_1            GO:0018243|GO:0018242|GO:0009100|GO:0006486
# TU Prostate Lapointe_38                                            GO:0060333
#
#                                                           Mature Seqeunce IDs  \
# Co-expression Signature
# COID Lung Bhattacharjee_24                                       MIMAT0004694
# SMCL Lung Bhattacharjee_61                                       MIMAT0000760
# AC Brain Sun_5                                      MIMAT0003307|MIMAT0002840
# GCT Seminoma Korkola_4                 MIMAT0000729|MIMAT0002172|MIMAT0000720
# ME Melanoma Hoek_50                                              MIMAT0003285
# ...                                                                       ...
# SRS Ovarian Hendrix_1                               MIMAT0003311|MIMAT0001639
# SRS Ovarian Hendrix_11                              MIMAT0004801|MIMAT0000703
# SRS Ovarian Hendrix_26                                           MIMAT0000771
# TU Prostate Lapointe_1      MIMAT0004801|MIMAT0000083|MIMAT0000082|MIMAT00...
# TU Prostate Lapointe_38                             MIMAT0003303|MIMAT0005791
#
#                             Hallmarks of Cancer  \
# Co-expression Signature
# COID Lung Bhattacharjee_24                    9
# SMCL Lung Bhattacharjee_61                    9
# AC Brain Sun_5                                8
# GCT Seminoma Korkola_4                        8
# ME Melanoma Hoek_50                           8
# ...                                         ...
# SRS Ovarian Hendrix_1                         0
# SRS Ovarian Hendrix_11                        0
# SRS Ovarian Hendrix_26                        0
# TU Prostate Lapointe_1                        0
# TU Prostate Lapointe_38                       0
#
#                             Self Sufficiency In Growth Signals  \
# Co-expression Signature
# COID Lung Bhattacharjee_24                                0.93
# SMCL Lung Bhattacharjee_61                                1.00
# AC Brain Sun_5                                            0.93
# GCT Seminoma Korkola_4                                    1.00
# ME Melanoma Hoek_50                                       1.00
# ...                                                        ...
# SRS Ovarian Hendrix_1                                     0.78
# SRS Ovarian Hendrix_11                                    0.32
# SRS Ovarian Hendrix_26                                    0.14
# TU Prostate Lapointe_1                                    0.40
# TU Prostate Lapointe_38                                   0.60
#
#                             Insensitivity To Antigrowth Signals  \
# Co-expression Signature
# COID Lung Bhattacharjee_24                                 0.93
# SMCL Lung Bhattacharjee_61                                 1.00
# AC Brain Sun_5                                             0.93
# GCT Seminoma Korkola_4                                     1.00
# ME Melanoma Hoek_50                                        1.00
# ...                                                         ...
# SRS Ovarian Hendrix_1                                      0.78
# SRS Ovarian Hendrix_11                                     0.32
# SRS Ovarian Hendrix_26                                     0.14
# TU Prostate Lapointe_1                                     0.40
# TU Prostate Lapointe_38                                    0.60
#
#                             Evading Apoptosis  \
# Co-expression Signature
# COID Lung Bhattacharjee_24               0.90
# SMCL Lung Bhattacharjee_61               1.00
# AC Brain Sun_5                           0.90
# GCT Seminoma Korkola_4                   0.94
# ME Melanoma Hoek_50                      0.87
# ...                                       ...
# SRS Ovarian Hendrix_1                    0.53
# SRS Ovarian Hendrix_11                   0.07
# SRS Ovarian Hendrix_26                   0.00
# TU Prostate Lapointe_1                   0.16
# TU Prostate Lapointe_38                  0.18
#
#                             Limitless Replicative Potential  \
# Co-expression Signature
# COID Lung Bhattacharjee_24                             0.81
# SMCL Lung Bhattacharjee_61                             0.81
# AC Brain Sun_5                                         0.51
# GCT Seminoma Korkola_4                                 0.52
# ME Melanoma Hoek_50                                    0.53
# ...                                                     ...
# SRS Ovarian Hendrix_1                                  0.39
# SRS Ovarian Hendrix_11                                 0.04
# SRS Ovarian Hendrix_26                                 0.00
# TU Prostate Lapointe_1                                 0.00
# TU Prostate Lapointe_38                                0.14
#
#                             Sustained Angiogenesis  \
# Co-expression Signature
# COID Lung Bhattacharjee_24                    1.00
# SMCL Lung Bhattacharjee_61                    1.00
# AC Brain Sun_5                                0.88
# GCT Seminoma Korkola_4                        1.00
# ME Melanoma Hoek_50                           0.92
# ...                                            ...
# SRS Ovarian Hendrix_1                         0.37
# SRS Ovarian Hendrix_11                        0.27
# SRS Ovarian Hendrix_26                        0.00
# TU Prostate Lapointe_1                        0.00
# TU Prostate Lapointe_38                       0.17
#
#                             Tissue Invasion And Metastasis  \
# Co-expression Signature
# COID Lung Bhattacharjee_24                            1.00
# SMCL Lung Bhattacharjee_61                            1.00
# AC Brain Sun_5                                        0.99
# GCT Seminoma Korkola_4                                1.00
# ME Melanoma Hoek_50                                   1.00
# ...                                                    ...
# SRS Ovarian Hendrix_1                                 0.53
# SRS Ovarian Hendrix_11                                0.31
# SRS Ovarian Hendrix_26                                0.26
# TU Prostate Lapointe_1                                0.23
# TU Prostate Lapointe_38                               0.48
#
#                             Genome Instability And Mutation  \
# Co-expression Signature
# COID Lung Bhattacharjee_24                             0.81
# SMCL Lung Bhattacharjee_61                             0.85
# AC Brain Sun_5                                         0.83
# GCT Seminoma Korkola_4                                 0.83
# ME Melanoma Hoek_50                                    0.83
# ...                                                     ...
# SRS Ovarian Hendrix_1                                  0.76
# SRS Ovarian Hendrix_11                                 0.40
# SRS Ovarian Hendrix_26                                 0.00
# TU Prostate Lapointe_1                                 0.40
# TU Prostate Lapointe_38                                0.47
#
#                             Tumor Promoting Inflammation  \
# Co-expression Signature
# COID Lung Bhattacharjee_24                          0.85
# SMCL Lung Bhattacharjee_61                          1.00
# AC Brain Sun_5                                      1.00
# GCT Seminoma Korkola_4                              0.95
# ME Melanoma Hoek_50                                 0.95
# ...                                                  ...
# SRS Ovarian Hendrix_1                               0.58
# SRS Ovarian Hendrix_11                              0.14
# SRS Ovarian Hendrix_26                              0.00
# TU Prostate Lapointe_1                              0.16
# TU Prostate Lapointe_38                             0.67
#
#                             Reprogramming Energy Metabolism  \
# Co-expression Signature
# COID Lung Bhattacharjee_24                             0.37
# SMCL Lung Bhattacharjee_61                             0.79
# AC Brain Sun_5                                         0.48
# GCT Seminoma Korkola_4                                 0.48
# ME Melanoma Hoek_50                                    0.79
# ...                                                     ...
# SRS Ovarian Hendrix_1                                  0.44
# SRS Ovarian Hendrix_11                                 0.05
# SRS Ovarian Hendrix_26                                 0.00
# TU Prostate Lapointe_1                                 0.67
# TU Prostate Lapointe_38                                0.34
#
#                             Evading Immune Detection    cancer
# Co-expression Signature
# COID Lung Bhattacharjee_24                      0.85      Lung
# SMCL Lung Bhattacharjee_61                      1.00      Lung
# AC Brain Sun_5                                  1.00     Brain
# GCT Seminoma Korkola_4                          0.95  Seminoma
# ME Melanoma Hoek_50                             0.95  Melanoma
# ...                                              ...       ...
# SRS Ovarian Hendrix_1                           0.58   Ovarian
# SRS Ovarian Hendrix_11                          0.14   Ovarian
# SRS Ovarian Hendrix_26                          0.00   Ovarian
# TU Prostate Lapointe_1                          0.16  Prostate
# TU Prostate Lapointe_38                         0.67  Prostate
#
# [314 rows x 14 columns]

# %% [markdown]
# Split up GO terms into a list

# %%
st8['GO Terms'] = [i.split('|') for i in st8['GO Terms']]
st8
# Out:
#                                                                      GO Terms  \
# Co-expression Signature
# COID Lung Bhattacharjee_24  [GO:0051384, GO:0050896, GO:0030155, GO:000759...
# SMCL Lung Bhattacharjee_61  [GO:0019226, GO:0007599, GO:0042127, GO:000759...
# AC Brain Sun_5              [GO:0019730, GO:0050867, GO:0042110, GO:000692...
# GCT Seminoma Korkola_4      [GO:0030301, GO:0042127, GO:0006631, GO:004590...
# ME Melanoma Hoek_50         [GO:0019226, GO:0008104, GO:0007599, GO:001922...
# ...                                                                       ...
# SRS Ovarian Hendrix_1                    [GO:0006139, GO:0010467, GO:0045449]
# SRS Ovarian Hendrix_11                   [GO:0019058, GO:0019083, GO:0031018]
# SRS Ovarian Hendrix_26                                           [GO:0008333]
# TU Prostate Lapointe_1       [GO:0018243, GO:0018242, GO:0009100, GO:0006486]
# TU Prostate Lapointe_38                                          [GO:0060333]
#
#                                                           Mature Seqeunce IDs  \
# Co-expression Signature
# COID Lung Bhattacharjee_24                                       MIMAT0004694
# SMCL Lung Bhattacharjee_61                                       MIMAT0000760
# AC Brain Sun_5                                      MIMAT0003307|MIMAT0002840
# GCT Seminoma Korkola_4                 MIMAT0000729|MIMAT0002172|MIMAT0000720
# ME Melanoma Hoek_50                                              MIMAT0003285
# ...                                                                       ...
# SRS Ovarian Hendrix_1                               MIMAT0003311|MIMAT0001639
# SRS Ovarian Hendrix_11                              MIMAT0004801|MIMAT0000703
# SRS Ovarian Hendrix_26                                           MIMAT0000771
# TU Prostate Lapointe_1      MIMAT0004801|MIMAT0000083|MIMAT0000082|MIMAT00...
# TU Prostate Lapointe_38                             MIMAT0003303|MIMAT0005791
#
#                             Hallmarks of Cancer  \
# Co-expression Signature
# COID Lung Bhattacharjee_24                    9
# SMCL Lung Bhattacharjee_61                    9
# AC Brain Sun_5                                8
# GCT Seminoma Korkola_4                        8
# ME Melanoma Hoek_50                           8
# ...                                         ...
# SRS Ovarian Hendrix_1                         0
# SRS Ovarian Hendrix_11                        0
# SRS Ovarian Hendrix_26                        0
# TU Prostate Lapointe_1                        0
# TU Prostate Lapointe_38                       0
#
#                             Self Sufficiency In Growth Signals  \
# Co-expression Signature
# COID Lung Bhattacharjee_24                                0.93
# SMCL Lung Bhattacharjee_61                                1.00
# AC Brain Sun_5                                            0.93
# GCT Seminoma Korkola_4                                    1.00
# ME Melanoma Hoek_50                                       1.00
# ...                                                        ...
# SRS Ovarian Hendrix_1                                     0.78
# SRS Ovarian Hendrix_11                                    0.32
# SRS Ovarian Hendrix_26                                    0.14
# TU Prostate Lapointe_1                                    0.40
# TU Prostate Lapointe_38                                   0.60
#
#                             Insensitivity To Antigrowth Signals  \
# Co-expression Signature
# COID Lung Bhattacharjee_24                                 0.93
# SMCL Lung Bhattacharjee_61                                 1.00
# AC Brain Sun_5                                             0.93
# GCT Seminoma Korkola_4                                     1.00
# ME Melanoma Hoek_50                                        1.00
# ...                                                         ...
# SRS Ovarian Hendrix_1                                      0.78
# SRS Ovarian Hendrix_11                                     0.32
# SRS Ovarian Hendrix_26                                     0.14
# TU Prostate Lapointe_1                                     0.40
# TU Prostate Lapointe_38                                    0.60
#
#                             Evading Apoptosis  \
# Co-expression Signature
# COID Lung Bhattacharjee_24               0.90
# SMCL Lung Bhattacharjee_61               1.00
# AC Brain Sun_5                           0.90
# GCT Seminoma Korkola_4                   0.94
# ME Melanoma Hoek_50                      0.87
# ...                                       ...
# SRS Ovarian Hendrix_1                    0.53
# SRS Ovarian Hendrix_11                   0.07
# SRS Ovarian Hendrix_26                   0.00
# TU Prostate Lapointe_1                   0.16
# TU Prostate Lapointe_38                  0.18
#
#                             Limitless Replicative Potential  \
# Co-expression Signature
# COID Lung Bhattacharjee_24                             0.81
# SMCL Lung Bhattacharjee_61                             0.81
# AC Brain Sun_5                                         0.51
# GCT Seminoma Korkola_4                                 0.52
# ME Melanoma Hoek_50                                    0.53
# ...                                                     ...
# SRS Ovarian Hendrix_1                                  0.39
# SRS Ovarian Hendrix_11                                 0.04
# SRS Ovarian Hendrix_26                                 0.00
# TU Prostate Lapointe_1                                 0.00
# TU Prostate Lapointe_38                                0.14
#
#                             Sustained Angiogenesis  \
# Co-expression Signature
# COID Lung Bhattacharjee_24                    1.00
# SMCL Lung Bhattacharjee_61                    1.00
# AC Brain Sun_5                                0.88
# GCT Seminoma Korkola_4                        1.00
# ME Melanoma Hoek_50                           0.92
# ...                                            ...
# SRS Ovarian Hendrix_1                         0.37
# SRS Ovarian Hendrix_11                        0.27
# SRS Ovarian Hendrix_26                        0.00
# TU Prostate Lapointe_1                        0.00
# TU Prostate Lapointe_38                       0.17
#
#                             Tissue Invasion And Metastasis  \
# Co-expression Signature
# COID Lung Bhattacharjee_24                            1.00
# SMCL Lung Bhattacharjee_61                            1.00
# AC Brain Sun_5                                        0.99
# GCT Seminoma Korkola_4                                1.00
# ME Melanoma Hoek_50                                   1.00
# ...                                                    ...
# SRS Ovarian Hendrix_1                                 0.53
# SRS Ovarian Hendrix_11                                0.31
# SRS Ovarian Hendrix_26                                0.26
# TU Prostate Lapointe_1                                0.23
# TU Prostate Lapointe_38                               0.48
#
#                             Genome Instability And Mutation  \
# Co-expression Signature
# COID Lung Bhattacharjee_24                             0.81
# SMCL Lung Bhattacharjee_61                             0.85
# AC Brain Sun_5                                         0.83
# GCT Seminoma Korkola_4                                 0.83
# ME Melanoma Hoek_50                                    0.83
# ...                                                     ...
# SRS Ovarian Hendrix_1                                  0.76
# SRS Ovarian Hendrix_11                                 0.40
# SRS Ovarian Hendrix_26                                 0.00
# TU Prostate Lapointe_1                                 0.40
# TU Prostate Lapointe_38                                0.47
#
#                             Tumor Promoting Inflammation  \
# Co-expression Signature
# COID Lung Bhattacharjee_24                          0.85
# SMCL Lung Bhattacharjee_61                          1.00
# AC Brain Sun_5                                      1.00
# GCT Seminoma Korkola_4                              0.95
# ME Melanoma Hoek_50                                 0.95
# ...                                                  ...
# SRS Ovarian Hendrix_1                               0.58
# SRS Ovarian Hendrix_11                              0.14
# SRS Ovarian Hendrix_26                              0.00
# TU Prostate Lapointe_1                              0.16
# TU Prostate Lapointe_38                             0.67
#
#                             Reprogramming Energy Metabolism  \
# Co-expression Signature
# COID Lung Bhattacharjee_24                             0.37
# SMCL Lung Bhattacharjee_61                             0.79
# AC Brain Sun_5                                         0.48
# GCT Seminoma Korkola_4                                 0.48
# ME Melanoma Hoek_50                                    0.79
# ...                                                     ...
# SRS Ovarian Hendrix_1                                  0.44
# SRS Ovarian Hendrix_11                                 0.05
# SRS Ovarian Hendrix_26                                 0.00
# TU Prostate Lapointe_1                                 0.67
# TU Prostate Lapointe_38                                0.34
#
#                             Evading Immune Detection    cancer
# Co-expression Signature
# COID Lung Bhattacharjee_24                      0.85      Lung
# SMCL Lung Bhattacharjee_61                      1.00      Lung
# AC Brain Sun_5                                  1.00     Brain
# GCT Seminoma Korkola_4                          0.95  Seminoma
# ME Melanoma Hoek_50                             0.95  Melanoma
# ...                                              ...       ...
# SRS Ovarian Hendrix_1                           0.58   Ovarian
# SRS Ovarian Hendrix_11                          0.14   Ovarian
# SRS Ovarian Hendrix_26                          0.00   Ovarian
# TU Prostate Lapointe_1                          0.16  Prostate
# TU Prostate Lapointe_38                         0.67  Prostate
#
# [314 rows x 14 columns]

# %% [markdown]
# Split up miRNAs into a list

# %%
st8['Mature Seqeunce IDs'] = [i.split('|') for i in st8['Mature Seqeunce IDs']]
st8
# Out:
#                                                                      GO Terms  \
# Co-expression Signature
# COID Lung Bhattacharjee_24  [GO:0051384, GO:0050896, GO:0030155, GO:000759...
# SMCL Lung Bhattacharjee_61  [GO:0019226, GO:0007599, GO:0042127, GO:000759...
# AC Brain Sun_5              [GO:0019730, GO:0050867, GO:0042110, GO:000692...
# GCT Seminoma Korkola_4      [GO:0030301, GO:0042127, GO:0006631, GO:004590...
# ME Melanoma Hoek_50         [GO:0019226, GO:0008104, GO:0007599, GO:001922...
# ...                                                                       ...
# SRS Ovarian Hendrix_1                    [GO:0006139, GO:0010467, GO:0045449]
# SRS Ovarian Hendrix_11                   [GO:0019058, GO:0019083, GO:0031018]
# SRS Ovarian Hendrix_26                                           [GO:0008333]
# TU Prostate Lapointe_1       [GO:0018243, GO:0018242, GO:0009100, GO:0006486]
# TU Prostate Lapointe_38                                          [GO:0060333]
#
#                                                           Mature Seqeunce IDs  \
# Co-expression Signature
# COID Lung Bhattacharjee_24                                     [MIMAT0004694]
# SMCL Lung Bhattacharjee_61                                     [MIMAT0000760]
# AC Brain Sun_5                                   [MIMAT0003307, MIMAT0002840]
# GCT Seminoma Korkola_4             [MIMAT0000729, MIMAT0002172, MIMAT0000720]
# ME Melanoma Hoek_50                                            [MIMAT0003285]
# ...                                                                       ...
# SRS Ovarian Hendrix_1                            [MIMAT0003311, MIMAT0001639]
# SRS Ovarian Hendrix_11                           [MIMAT0004801, MIMAT0000703]
# SRS Ovarian Hendrix_26                                         [MIMAT0000771]
# TU Prostate Lapointe_1      [MIMAT0004801, MIMAT0000083, MIMAT0000082, MIM...
# TU Prostate Lapointe_38                          [MIMAT0003303, MIMAT0005791]
#
#                             Hallmarks of Cancer  \
# Co-expression Signature
# COID Lung Bhattacharjee_24                    9
# SMCL Lung Bhattacharjee_61                    9
# AC Brain Sun_5                                8
# GCT Seminoma Korkola_4                        8
# ME Melanoma Hoek_50                           8
# ...                                         ...
# SRS Ovarian Hendrix_1                         0
# SRS Ovarian Hendrix_11                        0
# SRS Ovarian Hendrix_26                        0
# TU Prostate Lapointe_1                        0
# TU Prostate Lapointe_38                       0
#
#                             Self Sufficiency In Growth Signals  \
# Co-expression Signature
# COID Lung Bhattacharjee_24                                0.93
# SMCL Lung Bhattacharjee_61                                1.00
# AC Brain Sun_5                                            0.93
# GCT Seminoma Korkola_4                                    1.00
# ME Melanoma Hoek_50                                       1.00
# ...                                                        ...
# SRS Ovarian Hendrix_1                                     0.78
# SRS Ovarian Hendrix_11                                    0.32
# SRS Ovarian Hendrix_26                                    0.14
# TU Prostate Lapointe_1                                    0.40
# TU Prostate Lapointe_38                                   0.60
#
#                             Insensitivity To Antigrowth Signals  \
# Co-expression Signature
# COID Lung Bhattacharjee_24                                 0.93
# SMCL Lung Bhattacharjee_61                                 1.00
# AC Brain Sun_5                                             0.93
# GCT Seminoma Korkola_4                                     1.00
# ME Melanoma Hoek_50                                        1.00
# ...                                                         ...
# SRS Ovarian Hendrix_1                                      0.78
# SRS Ovarian Hendrix_11                                     0.32
# SRS Ovarian Hendrix_26                                     0.14
# TU Prostate Lapointe_1                                     0.40
# TU Prostate Lapointe_38                                    0.60
#
#                             Evading Apoptosis  \
# Co-expression Signature
# COID Lung Bhattacharjee_24               0.90
# SMCL Lung Bhattacharjee_61               1.00
# AC Brain Sun_5                           0.90
# GCT Seminoma Korkola_4                   0.94
# ME Melanoma Hoek_50                      0.87
# ...                                       ...
# SRS Ovarian Hendrix_1                    0.53
# SRS Ovarian Hendrix_11                   0.07
# SRS Ovarian Hendrix_26                   0.00
# TU Prostate Lapointe_1                   0.16
# TU Prostate Lapointe_38                  0.18
#
#                             Limitless Replicative Potential  \
# Co-expression Signature
# COID Lung Bhattacharjee_24                             0.81
# SMCL Lung Bhattacharjee_61                             0.81
# AC Brain Sun_5                                         0.51
# GCT Seminoma Korkola_4                                 0.52
# ME Melanoma Hoek_50                                    0.53
# ...                                                     ...
# SRS Ovarian Hendrix_1                                  0.39
# SRS Ovarian Hendrix_11                                 0.04
# SRS Ovarian Hendrix_26                                 0.00
# TU Prostate Lapointe_1                                 0.00
# TU Prostate Lapointe_38                                0.14
#
#                             Sustained Angiogenesis  \
# Co-expression Signature
# COID Lung Bhattacharjee_24                    1.00
# SMCL Lung Bhattacharjee_61                    1.00
# AC Brain Sun_5                                0.88
# GCT Seminoma Korkola_4                        1.00
# ME Melanoma Hoek_50                           0.92
# ...                                            ...
# SRS Ovarian Hendrix_1                         0.37
# SRS Ovarian Hendrix_11                        0.27
# SRS Ovarian Hendrix_26                        0.00
# TU Prostate Lapointe_1                        0.00
# TU Prostate Lapointe_38                       0.17
#
#                             Tissue Invasion And Metastasis  \
# Co-expression Signature
# COID Lung Bhattacharjee_24                            1.00
# SMCL Lung Bhattacharjee_61                            1.00
# AC Brain Sun_5                                        0.99
# GCT Seminoma Korkola_4                                1.00
# ME Melanoma Hoek_50                                   1.00
# ...                                                    ...
# SRS Ovarian Hendrix_1                                 0.53
# SRS Ovarian Hendrix_11                                0.31
# SRS Ovarian Hendrix_26                                0.26
# TU Prostate Lapointe_1                                0.23
# TU Prostate Lapointe_38                               0.48
#
#                             Genome Instability And Mutation  \
# Co-expression Signature
# COID Lung Bhattacharjee_24                             0.81
# SMCL Lung Bhattacharjee_61                             0.85
# AC Brain Sun_5                                         0.83
# GCT Seminoma Korkola_4                                 0.83
# ME Melanoma Hoek_50                                    0.83
# ...                                                     ...
# SRS Ovarian Hendrix_1                                  0.76
# SRS Ovarian Hendrix_11                                 0.40
# SRS Ovarian Hendrix_26                                 0.00
# TU Prostate Lapointe_1                                 0.40
# TU Prostate Lapointe_38                                0.47
#
#                             Tumor Promoting Inflammation  \
# Co-expression Signature
# COID Lung Bhattacharjee_24                          0.85
# SMCL Lung Bhattacharjee_61                          1.00
# AC Brain Sun_5                                      1.00
# GCT Seminoma Korkola_4                              0.95
# ME Melanoma Hoek_50                                 0.95
# ...                                                  ...
# SRS Ovarian Hendrix_1                               0.58
# SRS Ovarian Hendrix_11                              0.14
# SRS Ovarian Hendrix_26                              0.00
# TU Prostate Lapointe_1                              0.16
# TU Prostate Lapointe_38                             0.67
#
#                             Reprogramming Energy Metabolism  \
# Co-expression Signature
# COID Lung Bhattacharjee_24                             0.37
# SMCL Lung Bhattacharjee_61                             0.79
# AC Brain Sun_5                                         0.48
# GCT Seminoma Korkola_4                                 0.48
# ME Melanoma Hoek_50                                    0.79
# ...                                                     ...
# SRS Ovarian Hendrix_1                                  0.44
# SRS Ovarian Hendrix_11                                 0.05
# SRS Ovarian Hendrix_26                                 0.00
# TU Prostate Lapointe_1                                 0.67
# TU Prostate Lapointe_38                                0.34
#
#                             Evading Immune Detection    cancer
# Co-expression Signature
# COID Lung Bhattacharjee_24                      0.85      Lung
# SMCL Lung Bhattacharjee_61                      1.00      Lung
# AC Brain Sun_5                                  1.00     Brain
# GCT Seminoma Korkola_4                          0.95  Seminoma
# ME Melanoma Hoek_50                             0.95  Melanoma
# ...                                              ...       ...
# SRS Ovarian Hendrix_1                           0.58   Ovarian
# SRS Ovarian Hendrix_11                          0.14   Ovarian
# SRS Ovarian Hendrix_26                          0.00   Ovarian
# TU Prostate Lapointe_1                          0.16  Prostate
# TU Prostate Lapointe_38                         0.67  Prostate
#
# [314 rows x 14 columns]

# %% [markdown]
# ### Load up accessory data
# Load up mature sequence IDs to miRNA names

# %%
miRDb = pd.read_csv('data/hsa_mature.csv', header=0, index_col=1)
print(miRDb.shape)
# Out:
# (2656, 3)

# %% [markdown]
# ## Filter network into cross-cancer subnetwork
# ![Networks](https://genome.cshlp.org/content/22/11/2302/F4.large.jpg)
#
# Following the figure we will first reduce the network to only those associated to a hallmark of cancer.
#
# ### Filter 1:  associated to a hallmark of cancer

# %% [markdown]
# Then we use a function to pull out for each cluster the significant hallmarks of cancer based on an semantic similiarity score of 0.8. To facilitate this we will use a function:

# %%
hallmarks = ['Self Sufficiency In Growth Signals', 'Insensitivity To Antigrowth Signals', 'Evading Apoptosis', 'Limitless Replicative Potential', 'Sustained Angiogenesis', 'Tissue Invasion And Metastasis', 'Genome Instability And Mutation', 'Tumor Promoting Inflammation', 'Reprogramming Energy Metabolism', 'Evading Immune Detection']
def getHallmarks(scores, cutoff=0.8):
    return list((scores[scores>cutoff]).index)

# %% [markdown]
# Let's run it against all the clusters to identify which hallmark(s) are significant for each cluster:

# %%
clusterHallmarks = []
for cluster in st8.index:
    scores = st8.loc[cluster, hallmarks]
    clusterHallmarks.append(getHallmarks(scores))

# %% [markdown]
# And this back to the DataFrame as a new column 'sigHallmarks':

# %%
st8['sigHallmarks'] = clusterHallmarks
st8
# Out:
#                                                                      GO Terms  \
# Co-expression Signature
# COID Lung Bhattacharjee_24  [GO:0051384, GO:0050896, GO:0030155, GO:000759...
# SMCL Lung Bhattacharjee_61  [GO:0019226, GO:0007599, GO:0042127, GO:000759...
# AC Brain Sun_5              [GO:0019730, GO:0050867, GO:0042110, GO:000692...
# GCT Seminoma Korkola_4      [GO:0030301, GO:0042127, GO:0006631, GO:004590...
# ME Melanoma Hoek_50         [GO:0019226, GO:0008104, GO:0007599, GO:001922...
# ...                                                                       ...
# SRS Ovarian Hendrix_1                    [GO:0006139, GO:0010467, GO:0045449]
# SRS Ovarian Hendrix_11                   [GO:0019058, GO:0019083, GO:0031018]
# SRS Ovarian Hendrix_26                                           [GO:0008333]
# TU Prostate Lapointe_1       [GO:0018243, GO:0018242, GO:0009100, GO:0006486]
# TU Prostate Lapointe_38                                          [GO:0060333]
#
#                                                           Mature Seqeunce IDs  \
# Co-expression Signature
# COID Lung Bhattacharjee_24                                     [MIMAT0004694]
# SMCL Lung Bhattacharjee_61                                     [MIMAT0000760]
# AC Brain Sun_5                                   [MIMAT0003307, MIMAT0002840]
# GCT Seminoma Korkola_4             [MIMAT0000729, MIMAT0002172, MIMAT0000720]
# ME Melanoma Hoek_50                                            [MIMAT0003285]
# ...                                                                       ...
# SRS Ovarian Hendrix_1                            [MIMAT0003311, MIMAT0001639]
# SRS Ovarian Hendrix_11                           [MIMAT0004801, MIMAT0000703]
# SRS Ovarian Hendrix_26                                         [MIMAT0000771]
# TU Prostate Lapointe_1      [MIMAT0004801, MIMAT0000083, MIMAT0000082, MIM...
# TU Prostate Lapointe_38                          [MIMAT0003303, MIMAT0005791]
#
#                             Hallmarks of Cancer  \
# Co-expression Signature
# COID Lung Bhattacharjee_24                    9
# SMCL Lung Bhattacharjee_61                    9
# AC Brain Sun_5                                8
# GCT Seminoma Korkola_4                        8
# ME Melanoma Hoek_50                           8
# ...                                         ...
# SRS Ovarian Hendrix_1                         0
# SRS Ovarian Hendrix_11                        0
# SRS Ovarian Hendrix_26                        0
# TU Prostate Lapointe_1                        0
# TU Prostate Lapointe_38                       0
#
#                             Self Sufficiency In Growth Signals  \
# Co-expression Signature
# COID Lung Bhattacharjee_24                                0.93
# SMCL Lung Bhattacharjee_61                                1.00
# AC Brain Sun_5                                            0.93
# GCT Seminoma Korkola_4                                    1.00
# ME Melanoma Hoek_50                                       1.00
# ...                                                        ...
# SRS Ovarian Hendrix_1                                     0.78
# SRS Ovarian Hendrix_11                                    0.32
# SRS Ovarian Hendrix_26                                    0.14
# TU Prostate Lapointe_1                                    0.40
# TU Prostate Lapointe_38                                   0.60
#
#                             Insensitivity To Antigrowth Signals  \
# Co-expression Signature
# COID Lung Bhattacharjee_24                                 0.93
# SMCL Lung Bhattacharjee_61                                 1.00
# AC Brain Sun_5                                             0.93
# GCT Seminoma Korkola_4                                     1.00
# ME Melanoma Hoek_50                                        1.00
# ...                                                         ...
# SRS Ovarian Hendrix_1                                      0.78
# SRS Ovarian Hendrix_11                                     0.32
# SRS Ovarian Hendrix_26                                     0.14
# TU Prostate Lapointe_1                                     0.40
# TU Prostate Lapointe_38                                    0.60
#
#                             Evading Apoptosis  \
# Co-expression Signature
# COID Lung Bhattacharjee_24               0.90
# SMCL Lung Bhattacharjee_61               1.00
# AC Brain Sun_5                           0.90
# GCT Seminoma Korkola_4                   0.94
# ME Melanoma Hoek_50                      0.87
# ...                                       ...
# SRS Ovarian Hendrix_1                    0.53
# SRS Ovarian Hendrix_11                   0.07
# SRS Ovarian Hendrix_26                   0.00
# TU Prostate Lapointe_1                   0.16
# TU Prostate Lapointe_38                  0.18
#
#                             Limitless Replicative Potential  \
# Co-expression Signature
# COID Lung Bhattacharjee_24                             0.81
# SMCL Lung Bhattacharjee_61                             0.81
# AC Brain Sun_5                                         0.51
# GCT Seminoma Korkola_4                                 0.52
# ME Melanoma Hoek_50                                    0.53
# ...                                                     ...
# SRS Ovarian Hendrix_1                                  0.39
# SRS Ovarian Hendrix_11                                 0.04
# SRS Ovarian Hendrix_26                                 0.00
# TU Prostate Lapointe_1                                 0.00
# TU Prostate Lapointe_38                                0.14
#
#                             Sustained Angiogenesis  \
# Co-expression Signature
# COID Lung Bhattacharjee_24                    1.00
# SMCL Lung Bhattacharjee_61                    1.00
# AC Brain Sun_5                                0.88
# GCT Seminoma Korkola_4                        1.00
# ME Melanoma Hoek_50                           0.92
# ...                                            ...
# SRS Ovarian Hendrix_1                         0.37
# SRS Ovarian Hendrix_11                        0.27
# SRS Ovarian Hendrix_26                        0.00
# TU Prostate Lapointe_1                        0.00
# TU Prostate Lapointe_38                       0.17
#
#                             Tissue Invasion And Metastasis  \
# Co-expression Signature
# COID Lung Bhattacharjee_24                            1.00
# SMCL Lung Bhattacharjee_61                            1.00
# AC Brain Sun_5                                        0.99
# GCT Seminoma Korkola_4                                1.00
# ME Melanoma Hoek_50                                   1.00
# ...                                                    ...
# SRS Ovarian Hendrix_1                                 0.53
# SRS Ovarian Hendrix_11                                0.31
# SRS Ovarian Hendrix_26                                0.26
# TU Prostate Lapointe_1                                0.23
# TU Prostate Lapointe_38                               0.48
#
#                             Genome Instability And Mutation  \
# Co-expression Signature
# COID Lung Bhattacharjee_24                             0.81
# SMCL Lung Bhattacharjee_61                             0.85
# AC Brain Sun_5                                         0.83
# GCT Seminoma Korkola_4                                 0.83
# ME Melanoma Hoek_50                                    0.83
# ...                                                     ...
# SRS Ovarian Hendrix_1                                  0.76
# SRS Ovarian Hendrix_11                                 0.40
# SRS Ovarian Hendrix_26                                 0.00
# TU Prostate Lapointe_1                                 0.40
# TU Prostate Lapointe_38                                0.47
#
#                             Tumor Promoting Inflammation  \
# Co-expression Signature
# COID Lung Bhattacharjee_24                          0.85
# SMCL Lung Bhattacharjee_61                          1.00
# AC Brain Sun_5                                      1.00
# GCT Seminoma Korkola_4                              0.95
# ME Melanoma Hoek_50                                 0.95
# ...                                                  ...
# SRS Ovarian Hendrix_1                               0.58
# SRS Ovarian Hendrix_11                              0.14
# SRS Ovarian Hendrix_26                              0.00
# TU Prostate Lapointe_1                              0.16
# TU Prostate Lapointe_38                             0.67
#
#                             Reprogramming Energy Metabolism  \
# Co-expression Signature
# COID Lung Bhattacharjee_24                             0.37
# SMCL Lung Bhattacharjee_61                             0.79
# AC Brain Sun_5                                         0.48
# GCT Seminoma Korkola_4                                 0.48
# ME Melanoma Hoek_50                                    0.79
# ...                                                     ...
# SRS Ovarian Hendrix_1                                  0.44
# SRS Ovarian Hendrix_11                                 0.05
# SRS Ovarian Hendrix_26                                 0.00
# TU Prostate Lapointe_1                                 0.67
# TU Prostate Lapointe_38                                0.34
#
#                             Evading Immune Detection    cancer  \
# Co-expression Signature
# COID Lung Bhattacharjee_24                      0.85      Lung
# SMCL Lung Bhattacharjee_61                      1.00      Lung
# AC Brain Sun_5                                  1.00     Brain
# GCT Seminoma Korkola_4                          0.95  Seminoma
# ME Melanoma Hoek_50                             0.95  Melanoma
# ...                                              ...       ...
# SRS Ovarian Hendrix_1                           0.58   Ovarian
# SRS Ovarian Hendrix_11                          0.14   Ovarian
# SRS Ovarian Hendrix_26                          0.00   Ovarian
# TU Prostate Lapointe_1                          0.16  Prostate
# TU Prostate Lapointe_38                         0.67  Prostate
#
#                                                                  sigHallmarks
# Co-expression Signature
# COID Lung Bhattacharjee_24  [Self Sufficiency In Growth Signals, Insensiti...
# SMCL Lung Bhattacharjee_61  [Self Sufficiency In Growth Signals, Insensiti...
# AC Brain Sun_5              [Self Sufficiency In Growth Signals, Insensiti...
# GCT Seminoma Korkola_4      [Self Sufficiency In Growth Signals, Insensiti...
# ME Melanoma Hoek_50         [Self Sufficiency In Growth Signals, Insensiti...
# ...                                                                       ...
# SRS Ovarian Hendrix_1                                                      []
# SRS Ovarian Hendrix_11                                                     []
# SRS Ovarian Hendrix_26                                                     []
# TU Prostate Lapointe_1                                                     []
# TU Prostate Lapointe_38                                                    []
#
# [314 rows x 15 columns]

# %% [markdown]
# Now we can subset the network down to those with an association with a hallmark of cancer:

# %%
st8_hm = st8.loc[[True if len(st8.loc[cluster,'sigHallmarks'])>0 else False for cluster in st8.index]]
st8_hm
# Out:
#                                                                      GO Terms  \
# Co-expression Signature
# COID Lung Bhattacharjee_24  [GO:0051384, GO:0050896, GO:0030155, GO:000759...
# SMCL Lung Bhattacharjee_61  [GO:0019226, GO:0007599, GO:0042127, GO:000759...
# AC Brain Sun_5              [GO:0019730, GO:0050867, GO:0042110, GO:000692...
# GCT Seminoma Korkola_4      [GO:0030301, GO:0042127, GO:0006631, GO:004590...
# ME Melanoma Hoek_50         [GO:0019226, GO:0008104, GO:0007599, GO:001922...
# ...                                                                       ...
# SQ Lung Bhattacharjee_44    [GO:0009888, GO:0006928, GO:0030199, GO:003019...
# SQ Lung Bhattacharjee_45                                         [GO:0006334]
# SRS Ovarian Hendrix_72                                           [GO:0006334]
# TU Prostate Lapointe_37                                          [GO:0040012]
# TU Prostate Lapointe_7      [GO:0007517, GO:0030154, GO:0048701, GO:000693...
#
#                                                           Mature Seqeunce IDs  \
# Co-expression Signature
# COID Lung Bhattacharjee_24                                     [MIMAT0004694]
# SMCL Lung Bhattacharjee_61                                     [MIMAT0000760]
# AC Brain Sun_5                                   [MIMAT0003307, MIMAT0002840]
# GCT Seminoma Korkola_4             [MIMAT0000729, MIMAT0002172, MIMAT0000720]
# ME Melanoma Hoek_50                                            [MIMAT0003285]
# ...                                                                       ...
# SQ Lung Bhattacharjee_44                         [MIMAT0003882, MIMAT0016913]
# SQ Lung Bhattacharjee_45                                       [MIMAT0003330]
# SRS Ovarian Hendrix_72                                         [MIMAT0005930]
# TU Prostate Lapointe_37     [MIMAT0004975, MIMAT0002881, MIMAT0004563, MIM...
# TU Prostate Lapointe_7                                         [MIMAT0003244]
#
#                             Hallmarks of Cancer  \
# Co-expression Signature
# COID Lung Bhattacharjee_24                    9
# SMCL Lung Bhattacharjee_61                    9
# AC Brain Sun_5                                8
# GCT Seminoma Korkola_4                        8
# ME Melanoma Hoek_50                           8
# ...                                         ...
# SQ Lung Bhattacharjee_44                      1
# SQ Lung Bhattacharjee_45                      1
# SRS Ovarian Hendrix_72                        1
# TU Prostate Lapointe_37                       1
# TU Prostate Lapointe_7                        1
#
#                             Self Sufficiency In Growth Signals  \
# Co-expression Signature
# COID Lung Bhattacharjee_24                                0.93
# SMCL Lung Bhattacharjee_61                                1.00
# AC Brain Sun_5                                            0.93
# GCT Seminoma Korkola_4                                    1.00
# ME Melanoma Hoek_50                                       1.00
# ...                                                        ...
# SQ Lung Bhattacharjee_44                                  0.49
# SQ Lung Bhattacharjee_45                                  0.30
# SRS Ovarian Hendrix_72                                    0.30
# TU Prostate Lapointe_37                                   0.53
# TU Prostate Lapointe_7                                    0.76
#
#                             Insensitivity To Antigrowth Signals  \
# Co-expression Signature
# COID Lung Bhattacharjee_24                                 0.93
# SMCL Lung Bhattacharjee_61                                 1.00
# AC Brain Sun_5                                             0.93
# GCT Seminoma Korkola_4                                     1.00
# ME Melanoma Hoek_50                                        1.00
# ...                                                         ...
# SQ Lung Bhattacharjee_44                                   0.49
# SQ Lung Bhattacharjee_45                                   0.30
# SRS Ovarian Hendrix_72                                     0.30
# TU Prostate Lapointe_37                                    0.53
# TU Prostate Lapointe_7                                     0.73
#
#                             Evading Apoptosis  \
# Co-expression Signature
# COID Lung Bhattacharjee_24               0.90
# SMCL Lung Bhattacharjee_61               1.00
# AC Brain Sun_5                           0.90
# GCT Seminoma Korkola_4                   0.94
# ME Melanoma Hoek_50                      0.87
# ...                                       ...
# SQ Lung Bhattacharjee_44                 0.24
# SQ Lung Bhattacharjee_45                 0.06
# SRS Ovarian Hendrix_72                   0.06
# TU Prostate Lapointe_37                  0.29
# TU Prostate Lapointe_7                   0.37
#
#                             Limitless Replicative Potential  \
# Co-expression Signature
# COID Lung Bhattacharjee_24                             0.81
# SMCL Lung Bhattacharjee_61                             0.81
# AC Brain Sun_5                                         0.51
# GCT Seminoma Korkola_4                                 0.52
# ME Melanoma Hoek_50                                    0.53
# ...                                                     ...
# SQ Lung Bhattacharjee_44                               0.27
# SQ Lung Bhattacharjee_45                               0.34
# SRS Ovarian Hendrix_72                                 0.34
# TU Prostate Lapointe_37                                0.00
# TU Prostate Lapointe_7                                 0.34
#
#                             Sustained Angiogenesis  \
# Co-expression Signature
# COID Lung Bhattacharjee_24                    1.00
# SMCL Lung Bhattacharjee_61                    1.00
# AC Brain Sun_5                                0.88
# GCT Seminoma Korkola_4                        1.00
# ME Melanoma Hoek_50                           0.92
# ...                                            ...
# SQ Lung Bhattacharjee_44                      0.46
# SQ Lung Bhattacharjee_45                      0.00
# SRS Ovarian Hendrix_72                        0.00
# TU Prostate Lapointe_37                       0.15
# TU Prostate Lapointe_7                        0.89
#
#                             Tissue Invasion And Metastasis  \
# Co-expression Signature
# COID Lung Bhattacharjee_24                            1.00
# SMCL Lung Bhattacharjee_61                            1.00
# AC Brain Sun_5                                        0.99
# GCT Seminoma Korkola_4                                1.00
# ME Melanoma Hoek_50                                   1.00
# ...                                                    ...
# SQ Lung Bhattacharjee_44                              0.99
# SQ Lung Bhattacharjee_45                              0.25
# SRS Ovarian Hendrix_72                                0.25
# TU Prostate Lapointe_37                               0.84
# TU Prostate Lapointe_7                                0.72
#
#                             Genome Instability And Mutation  \
# Co-expression Signature
# COID Lung Bhattacharjee_24                             0.81
# SMCL Lung Bhattacharjee_61                             0.85
# AC Brain Sun_5                                         0.83
# GCT Seminoma Korkola_4                                 0.83
# ME Melanoma Hoek_50                                    0.83
# ...                                                     ...
# SQ Lung Bhattacharjee_44                               0.55
# SQ Lung Bhattacharjee_45                               0.81
# SRS Ovarian Hendrix_72                                 0.81
# TU Prostate Lapointe_37                                0.15
# TU Prostate Lapointe_7                                 0.65
#
#                             Tumor Promoting Inflammation  \
# Co-expression Signature
# COID Lung Bhattacharjee_24                          0.85
# SMCL Lung Bhattacharjee_61                          1.00
# AC Brain Sun_5                                      1.00
# GCT Seminoma Korkola_4                              0.95
# ME Melanoma Hoek_50                                 0.95
# ...                                                  ...
# SQ Lung Bhattacharjee_44                            0.29
# SQ Lung Bhattacharjee_45                            0.06
# SRS Ovarian Hendrix_72                              0.06
# TU Prostate Lapointe_37                             0.36
# TU Prostate Lapointe_7                              0.49
#
#                             Reprogramming Energy Metabolism  \
# Co-expression Signature
# COID Lung Bhattacharjee_24                             0.37
# SMCL Lung Bhattacharjee_61                             0.79
# AC Brain Sun_5                                         0.48
# GCT Seminoma Korkola_4                                 0.48
# ME Melanoma Hoek_50                                    0.79
# ...                                                     ...
# SQ Lung Bhattacharjee_44                               0.06
# SQ Lung Bhattacharjee_45                               0.00
# SRS Ovarian Hendrix_72                                 0.00
# TU Prostate Lapointe_37                                0.00
# TU Prostate Lapointe_7                                 0.34
#
#                             Evading Immune Detection    cancer  \
# Co-expression Signature
# COID Lung Bhattacharjee_24                      0.85      Lung
# SMCL Lung Bhattacharjee_61                      1.00      Lung
# AC Brain Sun_5                                  1.00     Brain
# GCT Seminoma Korkola_4                          0.95  Seminoma
# ME Melanoma Hoek_50                             0.95  Melanoma
# ...                                              ...       ...
# SQ Lung Bhattacharjee_44                        0.29      Lung
# SQ Lung Bhattacharjee_45                        0.06      Lung
# SRS Ovarian Hendrix_72                          0.06   Ovarian
# TU Prostate Lapointe_37                         0.36  Prostate
# TU Prostate Lapointe_7                          0.49  Prostate
#
#                                                                  sigHallmarks
# Co-expression Signature
# COID Lung Bhattacharjee_24  [Self Sufficiency In Growth Signals, Insensiti...
# SMCL Lung Bhattacharjee_61  [Self Sufficiency In Growth Signals, Insensiti...
# AC Brain Sun_5              [Self Sufficiency In Growth Signals, Insensiti...
# GCT Seminoma Korkola_4      [Self Sufficiency In Growth Signals, Insensiti...
# ME Melanoma Hoek_50         [Self Sufficiency In Growth Signals, Insensiti...
# ...                                                                       ...
# SQ Lung Bhattacharjee_44                     [Tissue Invasion And Metastasis]
# SQ Lung Bhattacharjee_45                    [Genome Instability And Mutation]
# SRS Ovarian Hendrix_72                      [Genome Instability And Mutation]
# TU Prostate Lapointe_37                      [Tissue Invasion And Metastasis]
# TU Prostate Lapointe_7                               [Sustained Angiogenesis]
#
# [157 rows x 15 columns]

# %% [markdown]
# ### Filter 2:  Same oncogenic process regulated by same miRNA across cancers

# %%
miRNAs = {}
for cluster in st8_hm.index:
    #print(row1)
    for miRNA in st8_hm.loc[cluster,'Mature Seqeunce IDs']:
        if not miRNA in miRNAs:
            miRNAs[miRNA] = []
        miRNAs[miRNA].append(cluster)

# %% [markdown]
# ### Filter 3:  miRNAs that regulate the same GO term & hallmark of cancer

# %%
cc_miRNAs = {}
cc_go_miRNAs = {}
for miRNA in miRNAs:
    # If have more than one cluster regulated by the miRNA
    if len(miRNAs[miRNA])>1:
        # If more than one cancer is regulated by the miRNA
        if len(st8_hm.loc[miRNAs[miRNA],'cancer'])>1:
            # Idenitfy which clusters have same go term -> hallmark relationships
            hm_dict = {}
            go_dict = {}
            # First, fill hm_dict with hallmarks and go_dict with go terms
            for cluster in miRNAs[miRNA]:
                # Build clusters so can test for common hallmarks
                for hm1 in st8_hm.loc[cluster,'sigHallmarks']:
                    if not hm1 in hm_dict:
                        hm_dict[hm1] = []
                    hm_dict[hm1].append(cluster)
                # Build clusters so can test for common GO terms
                for go1 in st8_hm.loc[cluster,'GO Terms']:
                    if not go1 in go_dict:
                        go_dict[go1] = []
                    go_dict[go1].append(cluster)
            # Second, find hallmarks in common across clusters, and refine subnetwork (cc_miRNAs)
            for hm1 in hm_dict:
                # If more than one cluster linked to same hallmark
                if len(hm_dict[hm1])>1:
                    if not miRNA in cc_miRNAs:
                        cc_miRNAs[miRNA] = {}
                    cc_miRNAs[miRNA][hm1] = miRNAs[miRNA]
            # Thrid, find go terms in common across clusters, and refine subnetwork
            for go1 in go_dict:
                # If more than one cluster linked to same GO term
                if len(go_dict[go1])>1:
                    # If had more than one cluster linked to same hallmark
                    if miRNA in cc_miRNAs:
                        if not miRNA in cc_go_miRNAs:
                            cc_go_miRNAs[miRNA] = {'hallmarks':cc_miRNAs[miRNA].keys(), 'clusters':miRNAs[miRNA], 'GO_terms':[]}
                        cc_go_miRNAs[miRNA]['GO_terms'].append(go1)
print(cc_miRNAs)
print(cc_go_miRNAs)
# Out:
# {'MIMAT0004694': {'Self Sufficiency In Growth Signals': ['COID Lung Bhattacharjee_24', 'GL Brain Bredel_30'], 'Insensitivity To Antigrowth Signals': ['COID Lung Bhattacharjee_24', 'GL Brain Bredel_30']}, 'MIMAT0003285': {'Self Sufficiency In Growth Signals': ['ME Melanoma Hoek_50', 'AD Lung Beer_6', 'AD Lung Bhattacharjee_30', 'B-CLL Leukemia Haslinger_62', 'CA Breast Sorlie_12', 'MM Myeloma Zhan_3'], 'Insensitivity To Antigrowth Signals': ['ME Melanoma Hoek_50', 'AD Lung Beer_6', 'AD Lung Bhattacharjee_30', 'B-CLL Leukemia Haslinger_62', 'CA Breast Sorlie_12', 'MM Myeloma Zhan_3'], 'Sustained Angiogenesis': ['ME Melanoma Hoek_50', 'AD Lung Beer_6', 'AD Lung Bhattacharjee_30', 'B-CLL Leukemia Haslinger_62', 'CA Breast Sorlie_12', 'MM Myeloma Zhan_3'], 'Tissue Invasion And Metastasis': ['ME Melanoma Hoek_50', 'AD Lung Beer_6', 'AD Lung Bhattacharjee_30', 'B-CLL Leukemia Haslinger_62', 'CA Breast Sorlie_12', 'MM Myeloma Zhan_3'], 'Genome Instability And Mutation': ['ME Melanoma Hoek_50', 'AD Lung Beer_6', 'AD Lung Bhattacharjee_30', 'B-CLL Leukemia Haslinger_62', 'CA Breast Sorlie_12', 'MM Myeloma Zhan_3']}, 'MIMAT0003332': {'Self Sufficiency In Growth Signals': ['CA Bladder Dyrskjot_82', 'AD Lung Beer_32'], 'Insensitivity To Antigrowth Signals': ['CA Bladder Dyrskjot_82', 'AD Lung Beer_32'], 'Sustained Angiogenesis': ['CA Bladder Dyrskjot_82', 'AD Lung Beer_32'], 'Tissue Invasion And Metastasis': ['CA Bladder Dyrskjot_82', 'AD Lung Beer_32'], 'Tumor Promoting Inflammation': ['CA Bladder Dyrskjot_82', 'AD Lung Beer_32'], 'Evading Immune Detection': ['CA Bladder Dyrskjot_82', 'AD Lung Beer_32']}, 'MIMAT0002879': {'Tissue Invasion And Metastasis': ['CA Colon Graudens_40', 'MM Myeloma Zhan_33']}, 'MIMAT0005881': {'Self Sufficiency In Growth Signals': ['IDC Breast Radvanyi_24', 'CA Bladder Dyrskjot_18'], 'Insensitivity To Antigrowth Signals': ['IDC Breast Radvanyi_24', 'CA Bladder Dyrskjot_18'], 'Tissue Invasion And Metastasis': ['IDC Breast Radvanyi_24', 'CA Bladder Dyrskjot_18']}, 'MIMAT0000690': {'Self Sufficiency In Growth Signals': ['AD Lung Bhattacharjee_41', 'SMCL Lung Bhattacharjee_36', 'SQ Lung Bhattacharjee_13'], 'Insensitivity To Antigrowth Signals': ['AD Lung Bhattacharjee_41', 'SMCL Lung Bhattacharjee_36', 'SQ Lung Bhattacharjee_13'], 'Tissue Invasion And Metastasis': ['AD Lung Bhattacharjee_41', 'SMCL Lung Bhattacharjee_36', 'SQ Lung Bhattacharjee_13'], 'Genome Instability And Mutation': ['AD Lung Bhattacharjee_41', 'SMCL Lung Bhattacharjee_36', 'SQ Lung Bhattacharjee_13']}, 'MIMAT0003323': {'Insensitivity To Antigrowth Signals': ['AD Ovarian Welsh_1', 'CA Bladder Dyrskjot_40', 'END Ovarian Hendrix_32'], 'Evading Apoptosis': ['AD Ovarian Welsh_1', 'CA Bladder Dyrskjot_40', 'END Ovarian Hendrix_32']}, 'MIMAT0004957': {'Self Sufficiency In Growth Signals': ['B-CLL Leukemia Haslinger_27', 'MM Myeloma Zhan_29', 'AD Lung Bhattacharjee_42', 'GLB Brain Sun_41'], 'Insensitivity To Antigrowth Signals': ['B-CLL Leukemia Haslinger_27', 'MM Myeloma Zhan_29', 'AD Lung Bhattacharjee_42', 'GLB Brain Sun_41'], 'Evading Apoptosis': ['B-CLL Leukemia Haslinger_27', 'MM Myeloma Zhan_29', 'AD Lung Bhattacharjee_42', 'GLB Brain Sun_41'], 'Genome Instability And Mutation': ['B-CLL Leukemia Haslinger_27', 'MM Myeloma Zhan_29', 'AD Lung Bhattacharjee_42', 'GLB Brain Sun_41']}, 'MIMAT0004926': {'Self Sufficiency In Growth Signals': ['HSCC Head-Neck Chung_9', 'GCT Seminoma Korkola_75'], 'Insensitivity To Antigrowth Signals': ['HSCC Head-Neck Chung_9', 'GCT Seminoma Korkola_75']}, 'MIMAT0003948': {'Insensitivity To Antigrowth Signals': ['AD Lung Beer_24', 'CCC Ovarian Hendrix_33'], 'Genome Instability And Mutation': ['AD Lung Beer_24', 'CCC Ovarian Hendrix_33']}, 'MIMAT0003310': {'Self Sufficiency In Growth Signals': ['CA Breast Sorlie_17', 'GCT Seminoma Korkola_93'], 'Insensitivity To Antigrowth Signals': ['CA Breast Sorlie_17', 'GCT Seminoma Korkola_93']}, 'MIMAT0004912': {'Self Sufficiency In Growth Signals': ['COID Lung Bhattacharjee_36', 'EN ...
# {'MIMAT0003285': {'hallmarks': dict_keys(['Self Sufficiency In Growth Signals', 'Insensitivity To Antigrowth Signals', 'Sustained Angiogenesis', 'Tissue Invasion And Metastasis', 'Genome Instability And Mutation']), 'clusters': ['ME Melanoma Hoek_50', 'AD Lung Beer_6', 'AD Lung Bhattacharjee_30', 'B-CLL Leukemia Haslinger_62', 'CA Breast Sorlie_12', 'MM Myeloma Zhan_3'], 'GO_terms': ['GO:0007596', 'GO:0007610', 'GO:0007167', 'GO:0006928', 'GO:0044267', 'GO:0001568', 'GO:0006366', 'GO:0016477', 'GO:0009887', 'GO:0008015', 'GO:0042060', 'GO:0001775', 'GO:0006357', 'GO:0008152', 'GO:0043687', 'GO:0032870', 'GO:0050896', 'GO:0001525', 'GO:0006468', 'GO:0030334', 'GO:0006464', 'GO:0015031', 'GO:0007268', 'GO:0007267', 'GO:0005975', 'GO:0044237']}, 'MIMAT0003332': {'hallmarks': dict_keys(['Self Sufficiency In Growth Signals', 'Insensitivity To Antigrowth Signals', 'Sustained Angiogenesis', 'Tissue Invasion And Metastasis', 'Tumor Promoting Inflammation', 'Evading Immune Detection']), 'clusters': ['CA Bladder Dyrskjot_82', 'AD Lung Beer_32'], 'GO_terms': ['GO:0030335', 'GO:0006928', 'GO:0050900', 'GO:0007166', 'GO:0001525', 'GO:0006935', 'GO:0009653', 'GO:0001568', 'GO:0009611', 'GO:0048514', 'GO:0016477', 'GO:0042127', 'GO:0009887', 'GO:0030334', 'GO:0008283', 'GO:0042060', 'GO:0006952', 'GO:0006954', 'GO:0006955', 'GO:0051272', 'GO:0048870', 'GO:0001816']}, 'MIMAT0005881': {'hallmarks': dict_keys(['Self Sufficiency In Growth Signals', 'Insensitivity To Antigrowth Signals', 'Tissue Invasion And Metastasis']), 'clusters': ['IDC Breast Radvanyi_24', 'CA Bladder Dyrskjot_18'], 'GO_terms': ['GO:0007154']}, 'MIMAT0000690': {'hallmarks': dict_keys(['Self Sufficiency In Growth Signals', 'Insensitivity To Antigrowth Signals', 'Tissue Invasion And Metastasis', 'Genome Instability And Mutation']), 'clusters': ['AD Lung Bhattacharjee_41', 'SMCL Lung Bhattacharjee_36', 'SQ Lung Bhattacharjee_13'], 'GO_terms': ['GO:0051384', 'GO:0030036', 'GO:0006928', 'GO:0007155', 'GO:0009653', 'GO:0000902', 'GO:0009611', 'GO:0016477', 'GO:0042127', 'GO:0008285', 'GO:0009887', 'GO:0030334', 'GO:0008283', 'GO:0032956', 'GO:0030041', 'GO:0048870', 'GO:0042493', 'GO:0043116', 'GO:0007411', 'GO:0007275', 'GO:0051271', 'GO:0007010']}, 'MIMAT0003323': {'hallmarks': dict_keys(['Insensitivity To Antigrowth Signals', 'Evading Apoptosis']), 'clusters': ['AD Ovarian Welsh_1', 'CA Bladder Dyrskjot_40', 'END Ovarian Hendrix_32'], 'GO_terms': ['GO:0006886', 'GO:0015031']}, 'MIMAT0004957': {'hallmarks': dict_keys(['Self Sufficiency In Growth Signals', 'Insensitivity To Antigrowth Signals', 'Evading Apoptosis', 'Genome Instability And Mutation']), 'clusters': ['B-CLL Leukemia Haslinger_27', 'MM Myeloma Zhan_29', 'AD Lung Bhattacharjee_42', 'GLB Brain Sun_41'], 'GO_terms': ['GO:0006334']}, 'MIMAT0004912': {'hallmarks': dict_keys(['Self Sufficiency In Growth Signals', 'Insensitivity To Antigrowth Signals', 'Sustained Angiogenesis', 'Tissue Invasion And Metastasis']), 'clusters': ['COID Lung Bhattacharjee_36', 'END Ovarian Hendrix_6'], 'GO_terms': ['GO:0001568', 'GO:0017015', 'GO:0001822', 'GO:0007155', 'GO:0007275']}, 'MIMAT0000100': {'hallmarks': dict_keys(['Self Sufficiency In Growth Signals', 'Insensitivity To Antigrowth Signals', 'Sustained Angiogenesis', 'Tissue Invasion And Metastasis']), 'clusters': ['END Ovarian Hendrix_6', 'HSCC Head-Neck Chung_1', 'AD Lung Beer_31', 'AD Lung Bhattacharjee_59', 'CCC Ovarian Hendrix_11'], 'GO_terms': ['GO:0001568', 'GO:0030154', 'GO:0006928', 'GO:0001501', 'GO:0030199', 'GO:0001503', 'GO:0007155', 'GO:0030512', 'GO:0009653', 'GO:0007275', 'GO:0030198', 'GO:0060346', 'GO:0030335', 'GO:0007160', 'GO:0060324', 'GO:0031175', 'GO:0007411', 'GO:0016477', 'GO:0009887', 'GO:0030182', 'GO:0032964', 'GO:0001957', 'GO:0001525', 'GO:0009611', 'GO:0048812']}, 'MIMAT0000681': {'hallmarks': dict_keys(['Self Sufficiency In Growth Signals', 'Insensitivity To Antigrowth Signals', 'Sustained Angiogenesis', 'Tissue Invasion And Metastasis']), 'clusters': [ ...

# %% [markdown]
# ### Build the network #1: cancer &rarr; miRNA &rarr; cluster &rarr; GO term &rarr; hallmark of cancer
# First need to initialize a networkx directed graph:

# %%
crossCancer = nx.DiGraph()

# %% [markdown]
# Add each cancer &rarr; miRNA &rarr; cluster &rarr; GO term &rarr; hallmark of cancer relationship:

# %%
for miRNA in cc_go_miRNAs:
    for cluster in cc_go_miRNAs[miRNA]['clusters']:
        # Add cancer -> miRNA
        crossCancer.add_edge(st8_hm.loc[cluster,'cancer'],miRDb.loc[miRNA,'Name'])
        crossCancer.nodes[st8_hm.loc[cluster,'cancer']]['group'] = 'cancer'
        crossCancer.nodes[miRDb.loc[miRNA,'Name']]['group'] = 'miRNA'
        # Add miRNA -> cluster
        crossCancer.add_edge(miRDb.loc[miRNA,'Name'],cluster)
        crossCancer.nodes[cluster]['group'] = 'cluster'
        # Add cluster -> GO term -> HM
        for go1 in cc_go_miRNAs[miRNA]['GO_terms']:
            crossCancer.add_edge(cluster,go1)
            crossCancer.nodes[go1]['group'] = 'go_term'
            for hm1 in cc_go_miRNAs[miRNA]['hallmarks']:
                crossCancer.add_edge(go1,hm1)
                crossCancer.nodes[hm1]['group'] = 'hallmark'

# %% [markdown]
# Write out the network as an interactive HTML page:

# %%
cc_nt = Network('800px','800px', directed=True, notebook=True)
#cc_nt.show_buttons(filter_=['physics'])
cc_nt.hrepulsion()
cc_nt.from_nx(crossCancer)
cc_nt.show('crossCancer_wGOTerms_EL.html')
# Out:
#         <iframe
#             width="800px"
#             height="800px"
#             src="crossCancer_wGOTerms_EL.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ### Build the network #2: cancer &rarr; miRNA &rarr; cluster &rarr; hallmark of cancer
# Now let's see what happens if we remove the GO terms from the network.
#
# First need to initialize a networkx directed graph:

# %%
crossCancer = nx.DiGraph()

# %% [markdown]
# Add each cancer &rarr; miRNA &rarr; cluster &rarr; hallmark of cancer relationship:

# %%
for miRNA in cc_go_miRNAs:
    for cluster in cc_go_miRNAs[miRNA]['clusters']:
        # Add cancer -> miRNA
        crossCancer.add_edge(st8_hm.loc[cluster,'cancer'],miRDb.loc[miRNA,'Name'])
        crossCancer.nodes[st8_hm.loc[cluster,'cancer']]['group'] = 'cancer'
        crossCancer.nodes[miRDb.loc[miRNA,'Name']]['group'] = 'miRNA'
        # Add miRNA -> cluster
        crossCancer.add_edge(miRDb.loc[miRNA,'Name'],cluster)
        crossCancer.nodes[cluster]['group'] = 'cluster'
        # Add cluster -> HM
        for hm1 in cc_go_miRNAs[miRNA]['hallmarks']:
            crossCancer.add_edge(cluster,hm1)
            crossCancer.nodes[hm1]['group'] = 'hallmark'

# %% [markdown]
# Write out the network as an interactive HTML page:

# %%
cc_nt = Network('800px','800px', directed=True, notebook=True)
#cc_nt.show_buttons(filter_=['physics'])
cc_nt.hrepulsion()
cc_nt.from_nx(crossCancer)
cc_nt.show('crossCancer_no_GOTerms_EL.html')
# Out:
#         <iframe
#             width="800px"
#             height="800px"
#             src="crossCancer_no_GOTerms_EL.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ### Build the network #3: cancer &rarr; miRNA &rarr; hallmark of cancer
# Now let's see what happens if we remove the clusters and GO terms from the network.
#
# First need to initialize a networkx directed graph:

# %%
crossCancer = nx.DiGraph()

# %% [markdown]
# Add each cancer &rarr; miRNA &rarr; hallmark of cancer relationship:

# %%
for miRNA in cc_go_miRNAs:
    for cluster in cc_go_miRNAs[miRNA]['clusters']:
        # Add cancer -> miRNA
        crossCancer.add_edge(st8_hm.loc[cluster,'cancer'],miRDb.loc[miRNA,'Name'])
        crossCancer.nodes[st8_hm.loc[cluster,'cancer']]['group'] = 'cancer'
        crossCancer.nodes[miRDb.loc[miRNA,'Name']]['group'] = 'miRNA'
        # Add miRNA -> HM
        for hm1 in cc_go_miRNAs[miRNA]['hallmarks']:
            crossCancer.add_edge(miRDb.loc[miRNA,'Name'],hm1)
            crossCancer.nodes[hm1]['group'] = 'hallmark'

# %% [markdown]
# Write out the network as an interactive HTML page:

# %%
cc_nt = Network('800px','800px', directed=True, notebook=True)
#cc_nt.show_buttons(filter_=['physics'])
cc_nt.from_nx(crossCancer)
cc_nt.show('crossCancer_no_Cluster_no_GOTerms_EL.html')
# Out:
#         <iframe
#             width="800px"
#             height="800px"
#             src="crossCancer_no_Cluster_no_GOTerms_EL.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
